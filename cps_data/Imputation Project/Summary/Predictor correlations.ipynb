# %%
import pandas as pd
corr = pd.read_csv('corrs')
corr.set_index(['Unnamed: 0'], inplace = True)
del corr.index.name

# %%
corr
# Out:
#                       Highest corr Second highest                Third
# F2441                 E32800: 0.84      N24: 0.32           XTOT: 0.24
# E32800                 F2441: 0.84      N24: 0.27            XTOT: 0.2
# N24                     XTOT: 0.77      EIC: 0.37          F2441: 0.32
# XTOT                     N24: 0.77      EIC: 0.25          F2441: 0.24
# E00200                 E18400: 0.4   E18500: 0.32  E19800_E20100: 0.14
# E00300                 E20400: 0.4   E18400: 0.36         E19200: 0.35
# E18400                 E00200: 0.4   E18500: 0.39         E00300: 0.36
# E20400                 E00300: 0.4   E19200: 0.35         E18500: 0.35
# E18500                E18400: 0.39   E20400: 0.35         E19200: 0.33
# EIC                      N24: 0.37     XTOT: 0.25         E02400: 0.11
# E19200                E20400: 0.35   E00300: 0.35         E18500: 0.33
# E00600                E20400: 0.34   E00300: 0.27         E18500: 0.26
# ...
