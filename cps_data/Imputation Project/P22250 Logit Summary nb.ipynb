# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)
P22250_logit = pd.read_csv('P22250_logit_sum.csv')
P22250_logit.set_index(['Response', 'Estimates'], inplace = True)

# %%
P22250_logit
# Out:
#                         (Intercept)           DSI           EIC         MARS1         MARS2         MARS3         MARS4        E00200        E00300        E00600    E00800        E00900        E01100        E01400        E01500        E01700        E02100    E02300        E02400        E03150     E03210        E03240     E03270        E03300        E17500        E18400        E18500        E19200        E19800        E20100        E20400    E32800
# Response Estimates
# 0        Coefficients  2.166256e+00  1.086986e+00  1.340685e+00  7.294433e-01 -6.081535e-02  3.949853e-01  1.102644e+00 -8.274275e-07 -2.772727e-06 -1.492856e-06 -0.000023 -1.003505e-08  5.829342e+00 -1.627521e-06 -3.740756e-07 -3.189665e-07  1.614217e-07  0.000031 -1.606383e-05 -4.981170e-05   0.000754 -7.318322e-08  -0.000024 -1.318800e-05 -6.877196e-06 -9.154276e-07 -3.615803e-05  8.413149e-08  8.094791e-08 -5.738434e-08 -4.928997e-05  0.000075
# ...
